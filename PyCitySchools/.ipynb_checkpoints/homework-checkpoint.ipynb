# %%
import pandas as pd
import numpy as np

# %%
schooldata_path = "Resources/schools_complete.csv"
studentdata_path = "Resources/students_complete.csv"

# %%
schooldata = pd.read_csv(schooldata_path)
studentdata = pd.read_csv(studentdata_path)

# %%
totalschools = schooldata["School ID"].count()
totalstudents = schooldata["size"].sum()
totalbudget = schooldata["budget"].sum()
average_math = studentdata['math_score'].mean()
average_read = studentdata["reading_score"].mean()
pass_math = studentdata.loc[studentdata['math_score']>=70]
pass_read = studentdata.loc[studentdata["reading_score"]>=70]
percent_math = len(pass_math)/totalstudents * 100
percent_read = len(pass_read)/totalstudents * 100 

percent_overall = (percent_math + percent_read) /2

# %%
district_summary = pd.DataFrame({"Total Schools" : totalschools,
                                 "Total Students" : totalstudents,
                                 "Total_Budget": totalbudget,
                                 "Average Math Score": average_math,
                                 "Average Reading Score": average_read,
                                 "% Passing Math": percent_math,
                                 "% Passing Reading" : percent_read,
                                 "Overall Passing Rate": [percent_overall]})

# %%
district_summary
# Out:
#    Total Schools  Total Students  Total_Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784       74.980853          85.805463
#
#    Overall Passing Rate
# 0             80.393158

# %%
newaverageread = district_summary["Average Reading Score"].map("{:,.2f}".format)

# %%
district_summary = pd.DataFrame({"Total Schools" : totalschools,
                                 "Total Students" : totalstudents,
                                 "Total_Budget": totalbudget,
                                 "Average Math Score": average_math,
                                 "Average Reading Score": newaverageread,
                                 "% Passing Math": percent_math,
                                 "% Passing Reading" : percent_read,
                                 "Overall Passing Rate": [percent_overall]})

# %%
district_summary
# Out:
#    Total Schools  Total Students  Total_Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#   Average Reading Score  % Passing Math  % Passing Reading  \
# 0                 81.88       74.980853          85.805463
#
#    Overall Passing Rate
# 0             80.393158

# %%
newaveragemath = district_summary["Average Math Score"].map("{:,.2f}".format)

# %%
district_summary = pd.DataFrame({"Total Schools" : totalschools,
                                 "Total Students" : totalstudents,
                                 "Total_Budget": totalbudget,
                                 "Average Math Score": newaveragemath,
                                 "Average Reading Score": newaverageread,
                                 "% Passing Math": percent_math,
                                 "% Passing Reading" : percent_read,
                                 "Overall Passing Rate": [percent_overall]})

# %%
newpercentmath = district_summary["% Passing Math"].map("{:,.2f}".format)

# %%
newpercentread = district_summary["% Passing Reading"].map("{:,.2f}".format)

# %%
district_summary = pd.DataFrame({"Total Schools" : totalschools,
                                 "Total Students" : totalstudents,
                                 "Total_Budget": totalbudget,
                                 "Average Math Score": newaveragemath,
                                 "Average Reading Score": newaverageread,
                                 "% Passing Math": newpercentmath,
                                 "% Passing Reading" : newpercentread,
                                 "Overall Passing Rate": [percent_overall]})

# %%
#District_Summary

district_summary
# Out:
#    Total Schools  Total Students  Total_Budget Average Math Score  \
# 0             15           39170      24649428              78.99
#
#   Average Reading Score % Passing Math % Passing Reading  Overall Passing Rate
# 0                 81.88          74.98             85.81             80.393158

# %%
schoolsummary = pd.merge(studentdata, schooldata, on=["school_name"])

# %%
schoolsummary = schoolsummary.drop(["School ID" , "Student ID", "gender", "grade", "student_name"], axis =1)

# %%
schoolsummary.drop_duplicates()
# Out:
#               school_name  reading_score  math_score      type  size   budget
# 0       Huang High School             66          79  District  2917  1910635
# 1       Huang High School             94          61  District  2917  1910635
# 2       Huang High School             90          60  District  2917  1910635
# 3       Huang High School             67          58  District  2917  1910635
# 4       Huang High School             97          84  District  2917  1910635
# ...                   ...            ...         ...       ...   ...      ...
# 39120  Thomas High School             72          99   Charter  1635  1043130
# 39126  Thomas High School             97          85   Charter  1635  1043130
# 39143  Thomas High School             71          93   Charter  1635  1043130
# 39151  Thomas High School             84          73   Charter  1635  1043130
# 39164  Thomas High School             97          76   Charter  1635  1043130
#
# [16273 rows x 6 columns]

# %%
school_name = schooldata.set_index("school_name")
school_type = school_name['type']
school_students = school_name['size']
school_budget = school_name['budget']
perstudent_budget = school_budget/school_students
schoolsummary
# Out:
#               school_name  reading_score  math_score      type  size   budget
# 0       Huang High School             66          79  District  2917  1910635
# 1       Huang High School             94          61  District  2917  1910635
# 2       Huang High School             90          60  District  2917  1910635
# 3       Huang High School             67          58  District  2917  1910635
# 4       Huang High School             97          84  District  2917  1910635
# ...                   ...            ...         ...       ...   ...      ...
# 39165  Thomas High School             99          90   Charter  1635  1043130
# 39166  Thomas High School             95          70   Charter  1635  1043130
# 39167  Thomas High School             73          84   Charter  1635  1043130
# 39168  Thomas High School             99          90   Charter  1635  1043130
# 39169  Thomas High School             95          75   Charter  1635  1043130
#
# [39170 rows x 6 columns]

# %%
index = schoolsummary.set_index("school_name")
grouped = index.groupby(["school_name"])
schoolsummary
# Out:
#               school_name  reading_score  math_score      type  size   budget
# 0       Huang High School             66          79  District  2917  1910635
# 1       Huang High School             94          61  District  2917  1910635
# 2       Huang High School             90          60  District  2917  1910635
# 3       Huang High School             67          58  District  2917  1910635
# 4       Huang High School             97          84  District  2917  1910635
# ...                   ...            ...         ...       ...   ...      ...
# 39165  Thomas High School             99          90   Charter  1635  1043130
# 39166  Thomas High School             95          70   Charter  1635  1043130
# 39167  Thomas High School             73          84   Charter  1635  1043130
# 39168  Thomas High School             99          90   Charter  1635  1043130
# 39169  Thomas High School             95          75   Charter  1635  1043130
#
# [39170 rows x 6 columns]

# %%
school_math = grouped["math_score"].mean()
school_read = grouped["reading_score"].mean()
school_math
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
#Session 2
total_student = grouped['size'].count()
grouped_math = pass_math.groupby("school_name")
passed_math = grouped_math['student_name'].count()/total_student*100

# %%
grouped_reading = pass_read.groupby("school_name")
passed_reading = grouped_reading['student_name'].count()/total_student*100
overall_pass = (passed_math + passed_reading)/2

# %%
school_summary = pd.DataFrame({"School Type": school_type,
                               "Total Students": school_students,
                               "Total School Budget": school_budget,
                              "Per Student Budget": perstudent_budget,
                              "Average Math Score": school_math,
                               "Average Reading Score" : school_read,
                               "% Passing Math" : passed_math,
                               "% Passing Reading" : passed_reading,
                               "Overall Passing Rate" : overall_pass
                               
                              
                              })

# %%
school_summary[]
# Out:
#                       School Type  Total Students  Total School Budget  \
# Bailey High School       District            4976              3124928
# Cabrera High School       Charter            1858              1081356
# Figueroa High School     District            2949              1884411
# Ford High School         District            2739              1763916
# Griffin High School       Charter            1468               917500
# Hernandez High School    District            4635              3022020
# Holden High School        Charter             427               248087
# Huang High School        District            2917              1910635
# Johnson High School      District            4761              3094650
# Pena High School          Charter             962               585858
# Rodriguez High School    District            3999              2547363
# Shelton High School       Charter            1761              1056600
# Thomas High School        Charter            1635              1043130
# Wilson High School        Charter            2283              1319574
# Wright High School        Charter            1800              1049400
#
#                        Per Student Budget  Average Math Score  \
# Bailey High School                  628.0           77.048432
# Cabrera High School                 582.0           83.061895
# Figueroa High School                639.0           76.711767
# Ford High School                    644.0           77.102592
# Griffin High School                 625.0           83.351499
# Hernandez High School               652.0           77.289752
# Holden High School                  581.0           83.803279
# Huang High School                   655.0           76.629414
# Johnson High School                 650.0           77.072464
# Pena High School                    609.0           83.839917
# Rodriguez High School               637.0           76.842711
# Shelton High School                 600.0           83.359455
# Thomas High School                  638.0           83.418349
# Wilson High School                  578.0           83.274201
# Wright High School                  583.0           83.682222
#
#                        Average Reading Score  % Passing Math  \
# Bailey High School                 81.033963       66.680064
# Cabrera High School                83.975780       94.133477
# Figueroa High School               81.158020       65.988471
# Ford High School                   80.746258       68.309602
# Griffin High School                83.816757       93.392371
# Hernandez High School              80.934412       66.752967
# Holden High School                 83.814988       92.505855
# Huang High School                  81.182722       65.683922
# Johnson High School                80.966394       66.057551
# Pena High School                   84.044699       94.594595
# Rodriguez High School              80.744686       66.366592
# Shelton High School                83.725724       93.867121
# Thomas High School                 83.848930       93.272171
# Wilson High School                 83.989488       93.867718
# Wright High School                 83.955000       93.333333
#
#                        % Passing Reading  Overall Passing Rate  \
# Bailey High School             81.933280             74.306672
# Cabrera High School            97.039828             95.586652
# Figueroa High School           80.739234             73.363852
# Ford High School               79.299014             73.804308
# Griffin High School            97.138965             95.265668
# Hernandez High School          80.862999             73.807983
# Holden High School             96.252927             94.379391
# Huang High School              81.316421             73.500171
# Johnson High School            81.222432             73.639992
# Pena High School               95.945946             95.270270
# Rodriguez High School          80.220055             73.293323
# Shelton High School            95.854628             94.860875
# Thomas High School             97.308869             95.290520
# Wilson High School             96.539641             95.203679
# Wright High School             96.611111             94.972222
#
#                       Spending Ranges (Per Student)
# Bailey High School                         $600-625
# Cabrera High School                           <$585
# Figueroa High School                       $600-625
# Ford High School                           $600-625
# Griffin High School                        $550-600
# Hernandez High School                      $625-650
# Holden High School                            <$585
# Huang High School                          $625-650
# Johnson High School                        $600-625
# Pena High School                           $550-600
# Rodriguez High School                      $600-625
# Shelton High School                           <$585
# Thomas High School                         $600-625
# Wilson High School                            <$585
# Wright High School                            <$585

# %%
top_summary= school_summary.loc[school_summary["Overall Passing Rate"]>90]

# %%
top_summary.sort_values(["Overall Passing Rate"], ascending=False).head()
# Out:
#                     School Type  Total Students  Total School Budget  \
# Cabrera High School     Charter            1858              1081356
# Thomas High School      Charter            1635              1043130
# Pena High School        Charter             962               585858
# Griffin High School     Charter            1468               917500
# Wilson High School      Charter            2283              1319574
#
#                      Per Student Budget  Average Math Score  \
# Cabrera High School               582.0           83.061895
# Thomas High School                638.0           83.418349
# Pena High School                  609.0           83.839917
# Griffin High School               625.0           83.351499
# Wilson High School                578.0           83.274201
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# Thomas High School               83.848930       93.272171          97.308869
# Pena High School                 84.044699       94.594595          95.945946
# Griffin High School              83.816757       93.392371          97.138965
# Wilson High School               83.989488       93.867718          96.539641
#
#                      Overall Passing Rate
# Cabrera High School             95.586652
# Thomas High School              95.290520
# Pena High School                95.270270
# Griffin High School             95.265668
# Wilson High School              95.203679

# %%
bottom_summary= school_summary.loc[school_summary["Overall Passing Rate"]<75]

# %%
bottom_summary.sort_values(["Overall Passing Rate"], ascending=True).head()
# Out:
#                       School Type  Total Students  Total School Budget  \
# Rodriguez High School    District            3999              2547363
# Figueroa High School     District            2949              1884411
# Huang High School        District            2917              1910635
# Johnson High School      District            4761              3094650
# Ford High School         District            2739              1763916
#
#                        Per Student Budget  Average Math Score  \
# Rodriguez High School               637.0           76.842711
# Figueroa High School                639.0           76.711767
# Huang High School                   655.0           76.629414
# Johnson High School                 650.0           77.072464
# Ford High School                    644.0           77.102592
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686       66.366592
# Figueroa High School               81.158020       65.988471
# Huang High School                  81.182722       65.683922
# Johnson High School                80.966394       66.057551
# Ford High School                   80.746258       68.309602
#
#                        % Passing Reading  Overall Passing Rate
# Rodriguez High School          80.220055             73.293323
# Figueroa High School           80.739234             73.363852
# Huang High School              81.316421             73.500171
# Johnson High School            81.222432             73.639992
# Ford High School               79.299014             73.804308

# %%
freshman = studentdata.loc[studentdata['grade']=='9th'].groupby("school_name")
freshman_math = freshman['math_score'].mean()
sophmore = studentdata.loc[studentdata['grade']=='10th'].groupby("school_name")
sophmore_math = sophmore['math_score'].mean()
junior = studentdata.loc[studentdata['grade']=='11th'].groupby("school_name")
junior_math = junior['math_score'].mean()
senior = studentdata.loc[studentdata['grade']=='12th'].groupby("school_name")
senior_math = senior['math_score'].mean()

math_summary = pd.DataFrame({"9th": freshman_math,
                             "10th": sophmore_math,
                             "11th": junior_math,
                             "12th": senior_math
    
})

# %%
math_summary.head()
# Out:
#                             9th       10th       11th       12th
# school_name
# Bailey High School    77.083676  76.996772  77.515588  76.492218
# Cabrera High School   83.094697  83.154506  82.765560  83.277487
# Figueroa High School  76.403037  76.539974  76.884344  77.151369
# Ford High School      77.361345  77.672316  76.918058  76.179963
# Griffin High School   82.044010  84.229064  83.842105  83.356164

# %%
freshman = studentdata.loc[studentdata['grade']=='9th'].groupby("school_name")
freshman_read = freshman['reading_score'].mean()
sophmore = studentdata.loc[studentdata['grade']=='10th'].groupby("school_name")
sophmore_read = sophmore['reading_score'].mean()
junior = studentdata.loc[studentdata['grade']=='11th'].groupby("school_name")
junior_read = junior['reading_score'].mean()
senior = studentdata.loc[studentdata['grade']=='12th'].groupby("school_name")
senior_read = senior['reading_score'].mean()

read_summary = pd.DataFrame({"9th": freshman_read,
                             "10th": sophmore_read,
                             "11th": junior_read,
                             "12th": senior_read
    
})

# %%
read_summary.head()
# Out:
#                             9th       10th       11th       12th
# school_name
# Bailey High School    81.303155  80.907183  80.945643  80.912451
# Cabrera High School   83.676136  84.253219  83.788382  84.287958
# Figueroa High School  81.198598  81.408912  80.640339  81.384863
# Ford High School      80.632653  81.262712  80.403642  80.662338
# Griffin High School   83.369193  83.706897  84.288089  84.013699

# %%
bins = [0,600,625,650,675]

spending_range = ['<$600','$600-625','$625-650','$650-675']

# %%
school_summary["Spending Ranges (Per Student)"] = pd.cut(school_summary["Per Student Budget"], bins, labels=range)
spend_summary = school_summary.groupby("Spending Ranges (Per Student)")
spend_summary = spend_summary[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "Overall Passing Rate"]]

# %%
spend_summary.mean()
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$585                                   83.436210              83.892196
# $550-600                                83.595708              83.930728
# $600-625                                78.032719              81.416375
# $625-650                                76.959583              81.058567
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# <$585                               93.541501          96.459627
# $550-600                            93.993483          96.542455
# $600-625                            71.112408          83.453814
# $625-650                            66.218444          81.089710
#
#                                Overall Passing Rate
# Spending Ranges (Per Student)
# <$585                                     95.000564
# $550-600                                  95.267969
# $600-625                                  77.283111
# $625-650                                  73.654077

# %%
school_summary['Total Students'].describe()
# Out:
# count      15.000000
# mean     2611.333333
# std      1420.915282
# min       427.000000
# 25%      1698.000000
# 50%      2283.000000
# 75%      3474.000000
# max      4976.000000
# Name: Total Students, dtype: float64

# %%
bindos = [0,2000,3500,5000]
size_range = ['Small','Medium','Large']

# %%
school_summary["School Size"] = pd.cut(school_summary["Total Students"], 
                                                         bindos, labels=size_range)

# %%
size_summary = school_summary.groupby("School Size")
size_summary = size_summary[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "Overall Passing Rate"]]

# %%
size_summary.mean()
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small                 83.502373              83.883125       93.585560
# Medium                78.429493              81.769122       73.462428
# Large                 77.063340              80.919864       66.464293
#
#              % Passing Reading  Overall Passing Rate
# School Size
# Small                96.593182             95.089371
# Medium               84.473577             78.968003
# Large                81.059691             73.761992

# %%
type_summary = school_summary.groupby('School Type')
type_summary = type_summary[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "Overall Passing Rate"]]

# %%
type_summary.mean()
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  Overall Passing Rate
# School Type
# Charter              96.586489             95.103660
# District             80.799062             73.673757

# %%
###Done!
